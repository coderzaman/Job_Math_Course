# %% [markdown]
# <a href="https://colab.research.google.com/github/coderzaman/Job_Math_Course/blob/main/2_%E0%A6%A8%E0%A7%8B%E0%A6%9F_%E0%A6%AE%E0%A7%8C%E0%A6%B2%E0%A6%BF%E0%A6%95_%E0%A6%93_%E0%A6%B8%E0%A6%B9%E0%A6%AE%E0%A7%8C%E0%A6%B2%E0%A6%BF%E0%A6%95_%E0%A6%B8%E0%A6%82%E0%A6%96%E0%A7%8D%E0%A6%AF%E0%A6%BE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📝 নোট: মৌলিক ও সহমৌলিক সংখ্যা
#
# আজকের পাঠে আমরা শিখব কীভাবে খুব সহজে মৌলিক ও সহমৌলিক সংখ্যা নির্ণয় করা যায়।
#
# ---
#
# ### ১. সহমৌলিক সংখ্যা (Co-prime Numbers)
#
# দুটি সংখ্যার মধ্যে **১ (এক)** ছাড়া যদি অন্য কোনো সাধারণ গুণনীয়ক (Common Factor) না থাকে, তবে সংখ্যা দুটিকে পরস্পরের **সহমৌলিক সংখ্যা** বলে।
#
# > **লক্ষ্যণীয়:** সহমৌলিক হতে হলে সংখ্যা দুটিকে মৌলিক হতে হবে—এমন কোনো বাধ্যবাধকতা নেই। যৌগিক সংখ্যাও সহমৌলিক হতে পারে।
#
# **উদাহরণ ১: (২, ৩)**
#
# * ২ এর গুণনীয়ক: ১, ২
# * ৩ এর গুণনীয়ক: ১, ৩
# * সাধারণ গুণনীয়ক: ১
#  এরা সহমৌলিক।
#
# **উদাহরণ ২: (৮, ২১)**
#
# * ৮ এর গুণনীয়ক: **১**, ২, ৪, ৮
# * ২১ এর গুণনীয়ক: **১**, ৩, ৭, ২১
# * এখানে ১ ছাড়া অন্য কোনো সাধারণ গুণনীয়ক নেই।
#  ৮ এবং ২১ সহমৌলিক।
#
# #### 🚀 সহমৌলিক চেনার সুপার শর্টকাট (কাটাকাটি মেথড)
#
# দুটি সংখ্যাকে ভগ্নাংশ বা ভাগ আকারে লিখুন। যদি তাদের কোনো সংখ্যা দিয়ে কাটাকাটি করা **না যায়**, তবে তারা সহমৌলিক। আর কাটাকাটি করা **গেলে** তারা সহমৌলিক নয়।
#
# * **চেক (৮, ২১):**   কোনো সংখ্যা দিয়েই কাটাকাটি যায় না। তাই এরা **সহমৌলিক**।
# * **চেক (৬, ৮):**   ২ দিয়ে কাটাকাটি করা যায় ()। তাই এরা **সহমৌলিক নয়**।
#
# ---
#
# ### ২. স্বাভাবিক সংখ্যা (Natural Numbers)
#
# স্বাভাবিক সংখ্যা বা ধনাত্মক অখণ্ড সংখ্যা {১, ২, ৩, ৪, ৫...} কে তিন ভাগে ভাগ করা যায়:
#
# 1. **১ (এক):** এটি মৌলিকও নয়, যৌগিকও নয়। (স্বতন্ত্র সংখ্যা)।
# 2. **মৌলিক সংখ্যা (Prime):** যার মাত্র দুটি গুণনীয়ক আছে (১ এবং ওই সংখ্যা)। যেমন: ২, ৩, ৫, ৭, ১১।
# 3. **যৌগিক বা অমৌলিক সংখ্যা (Composite):** যার দুইয়ের অধিক গুণনীয়ক আছে। যেমন: ৪, ৬, ৮, ৯, ১০।
#
# ---
#
# ### ৩. ১ থেকে ১০০ পর্যন্ত মৌলিক সংখ্যা
#
# ১-১০০ এর মধ্যে মোট মৌলিক সংখ্যা **২৫টি**। মনে রাখার জন্য এই কোডটি (মোবাইল নাম্বারের মতো) মুখস্থ রাখতে পারেন:
#
# > **কোড:** ৪৪ ২২৩ ২২৩ ২১
#
# **বিস্তারিত তালিকা:**
#
# * ১-১০ (৪টি): ২, ৩, ৫, ৭
# * ১১-২০ (৪টি): ১১, ১৩, ১৭, ১৯
# * ২১-৩০ (২টি): ২৩, ২৯
# * ৩১-৪০ (২টি): ৩১, ৩৭
# * ৪১-৫০ (২টি): ৪১, ৪৩, ৪৭
# * ৫১-৬০ (২টি): ৫৩, ৫৯
# * ৬১-৭০ (২টি): ৬১, ৬৭
# * ৭১-৮০ (৩টি): ৭১, ৭৩, ৭৯
# * ৮১-৯০ (২টি): ৮৩, ৮৯
# * ৯১-১০০ (১টি): ৯৭
#
# **বিশেষ তথ্য:**
#
# * **২** হলো সবচেয়ে ছোট মৌলিক সংখ্যা এবং একমাত্র **জোড়** মৌলিক সংখ্যা।
#
# ---
#
# ### ৪. ১-১০০ এর মধ্যে মৌলিক সংখ্যা চেনার উপায় (Checking Methods)
#
# যেকোনো সংখ্যা মৌলিক কি না, তা বুঝতে নিচের ধাপগুলো চেক করবেন:
#
# 1. **জোড় সংখ্যা:** ২ ছাড়া অন্য কোনো জোড় সংখ্যা মৌলিক নয়।
# 2. **৫ বা ০:** সংখ্যার শেষে ৫ বা ০ থাকলে তা মৌলিক নয় (৫ দ্বারা বিভাজ্য)।
# 3. **৩ দ্বারা বিভাজ্য:** অঙ্কগুলোর যোগফল ৩ দিয়ে ভাগ গেলে সংখ্যাটি মৌলিক নয়। (যেমন: ৮৭  ৮+৭=১৫, যা ৩ দিয়ে ভাগ যায়)।
# 4. **৭ দ্বারা বিভাজ্য:** কিছু খটকা লাগা সংখ্যা বিশেষ করে চেক করবেন: **৪৯, ৭৭, ৯১**। এগুলো ৭ দিয়ে ভাগ যায়, তাই মৌলিক নয়।
#
# #### 📝 অনুশিলনী ১ (আপনার দেওয়া সংখ্যাগুলোর সমাধান)
#
# নিচে আপনার দেওয়া সংখ্যাগুলো যাচাই করা হলো:
#
# | সংখ্যা | মন্তব্য/যাচাই | ফলাফল |
# | --- | --- | --- |
# | **৮৭** | ৮+৭=১৫ (৩ দ্বারা বিভাজ্য) | মৌলিক নয় |
# | **৯১** | ৭  ১৩ = ৯১ (৭ দ্বারা বিভাজ্য) | মৌলিক নয় |
# | **২৩** | কোনো কিছু দিয়ে ভাগ যায় না | **মৌলিক** |
# | **৩৪** | জোড় সংখ্যা | মৌলিক নয় |
# | **৫৬** | জোড় সংখ্যা | মৌলিক নয় |
# | **৫৩** | কোনো কিছু দিয়ে ভাগ যায় না | **মৌলিক** |
# | **৭৫** | শেষে ৫ আছে | মৌলিক নয় |
# | **৭৭** | ৭  ১১ = ৭৭ | মৌলিক নয় |
# | **৬৭** | কোনো কিছু দিয়ে ভাগ যায় না | **মৌলিক** |
# | **৭৩** | কোনো কিছু দিয়ে ভাগ যায় না | **মৌলিক** |
# | **৫৭** | ৫+৭=১২ (৩ দ্বারা বিভাজ্য) | মৌলিক নয় |
# | **৪৭** | কোনো কিছু দিয়ে ভাগ যায় না | **মৌলিক** |
# | **৯৭** | কোনো কিছু দিয়ে ভাগ যায় না | **মৌলিক** |
#
# ---
#
# ### ৫. ১০০ এর চেয়ে বড় সংখ্যার ক্ষেত্রে নিয়ম
#
# বড় সংখ্যা মৌলিক কি না তা চেক করার জন্য **বর্গমূল (Square Root)** মেথড ব্যবহার করতে হয়।
#
# **নিয়ম:**
#
# 1. সংখ্যাটির কাছাকাছি পূর্ণবর্গ সংখ্যার বর্গমূল বের করুন।
# 2. সেই বর্গমূলের চেয়ে ছোট বা সমান মৌলিক সংখ্যাগুলো দিয়ে ভাগ করার চেষ্টা করুন।
# 3. যদি কোনোটি দিয়েই ভাগ না যায়, তবে সেটি মৌলিক।
#
# #### 📝 অনুশিলনী ২ (আপনার দেওয়া বড় সংখ্যাগুলোর সমাধান)
#
# **১. ১৮১ (181)**
#
# * ১৮১ এর কাছাকাছি বর্গমূল  (কারণ , )।
# * ১৩ পর্যন্ত মৌলিক সংখ্যা: ২, ৩, ৫, ৭, ১১, ১৩।
# * চেক: এটি ২, ৩, ৫ দিয়ে যায় না। ৭ দিয়েও যায় না, ১১ দিয়েও না, ১৩ দিয়েও না।
# *  **১৮১ মৌলিক সংখ্যা।**
#
# **২. ২০৫ (205)**
#
# * শেষে ৫ আছে।
# *  **মৌলিক নয়** (৫ দ্বারা বিভাজ্য)।
#
# **৩. ২২১ (221)**
#
# * বর্গমূল । আমরা ১৩ পর্যন্ত চেক করব।
# * ২, ৩, ৫ দিয়ে যায় না। ৭ দিয়ে যায় না।
# * ১৩ দিয়ে চেক:  (মিলে গেছে)।
# *  **মৌলিক নয়**।
#
# **৪. ১৩৩ (133)**
#
# * বর্গমূল ।
# * ২, ৩, ৫ দিয়ে যায় না।
# * ৭ দিয়ে চেক:  (মিলে গেছে)।
# *  **মৌলিক নয়**।
#
# **৫. ২৫৭ (257)**
#
# * বর্গমূল । আমরা ১৩ পর্যন্ত চেক করব (কারণ পরবর্তী মৌলিক ১৭, যা ১৬ এর চেয়ে বড়)।
# * চেক করব: ২, ৩, ৫, ৭, ১১, ১৩ দিয়ে।
# * কোনোটি দিয়েই ভাগ করা যায় না।
# *  **২৫৭ মৌলিক সংখ্যা।**
#
# **৬. ৩৩৭ (337)**
#
# * বর্গমূল । আমরা ১৭ পর্যন্ত চেক করব।
# * চেক করব: ২, ৩, ৫, ৭, ১১, ১৩, ১৭ দিয়ে।
# * ৩৩৭ কোনোটি দিয়েই বিভাজ্য নয়।
# *  **৩৩৭ মৌলিক সংখ্যা।**
